# %%
import pandas as pd
import censusdata

# %%
df = pd.read_csv("breach_report.csv")

# %%
df['Type of Breach'].value_counts()
# Out:
# Hacking/IT Incident                                                                                    2528
# Unauthorized Access/Disclosure                                                                         1269
# Theft                                                                                                   976
# Loss                                                                                                    206
# Improper Disposal                                                                                       106
# Other                                                                                                    75
# Theft, Unauthorized Access/Disclosure                                                                    25
# Loss, Theft                                                                                              15
# Unknown                                                                                                  10
# Hacking/IT Incident, Unauthorized Access/Disclosure                                                       8
# Other, Unauthorized Access/Disclosure                                                                     6
# Other, Theft                                                                                              3
# Improper Disposal, Loss                                                                                   3
# Loss, Unauthorized Access/Disclosure                                                                      3
# Improper Disposal, Loss, Theft                                                                            3
# Loss, Other                                                                                               2
# Other, Theft, Unauthorized Access/Disclosure                                                              2
# Hacking/IT Incident, Other                                                                                2
# Hacking/IT Incident, Theft, Unauthorized Access/Disclosure                                                2
# Other, Unknown                                                                                            2
# Improper Disposal, Unauthorized Access/Disclosure                                                         1
# Loss, Unknown                                                                                             1
# Improper Disposal, Theft, Unauthorized Access/Disclosure                                                  1
# Loss, Other, Theft                                                                                        1
# Hacking/IT Incident, Improper Disposal, Loss, Other, Theft, Unauthorized Access/Disclosure, Unknown       1
# Hacking/IT Incident, Theft                                                                                1
# Improper Disposal, Theft                                                                                  1
# Hacking/IT Incident, Other, Unauthorized Access/Disclosure                                                1
# Loss, Theft, Unauthorized Access/Disclosure, Unknown                                                      1
# Loss, Unauthorized Access/Disclosure, Unknown                                                             1
# Name: Type of Breach, dtype: int64

# %%
# split column by ',' and keep only the first column
df['First Breach Type'] = df['Type of Breach'].str.split(',').str[0]

# %%
df.to_csv('breach_report.csv', index=False)

# %%
df.head()
# Out:
#                Name of Covered Entity State  Covered Entity Type  \
# 0           Bone & Joint Clinic, S.C.    WI  Healthcare Provider
# 1                  ZOLL Services LLC     MA  Healthcare Provider
# 2         Colquitt Complete Care, LLC    GA  Healthcare Provider
# 3                Beacon Health System    IN  Healthcare Provider
# 4  Wichita Urology Group, PA (“WUG”)     KS  Healthcare Provider
#
#    Individuals Affected Breach Submission Date  \
# 0              105094.0             03/13/2023
# 1              997097.0             03/10/2023
# 2                1282.0             03/10/2023
# 3                3117.0             03/10/2023
# 4                1493.0             03/08/2023
#
#                    Type of Breach Location of Breached Information  \
# 0             Hacking/IT Incident                   Network Server
# 1             Hacking/IT Incident                   Network Server
# 2             Hacking/IT Incident                   Network Server
# 3  Unauthorized Access/Disclosure        Electronic Medical Record
# 4             Hacking/IT Incident                   Network Server
#
#   Business Associate Present Web Description               First Breach Type
# 0                         No             NaN             Hacking/IT Incident
# 1                         No             NaN             Hacking/IT Incident
# 2                        Yes             NaN             Hacking/IT Incident
# 3                         No             NaN  Unauthorized Access/Disclosure
# 4                         No             NaN             Hacking/IT Incident

# %%
df['State_AB'] = df['State']

# %%
df.head()
# Out:
#                Name of Covered Entity State  Covered Entity Type  \
# 0           Bone & Joint Clinic, S.C.    WI  Healthcare Provider
# 1                  ZOLL Services LLC     MA  Healthcare Provider
# 2         Colquitt Complete Care, LLC    GA  Healthcare Provider
# 3                Beacon Health System    IN  Healthcare Provider
# 4  Wichita Urology Group, PA (“WUG”)     KS  Healthcare Provider
#
#    Individuals Affected Breach Submission Date  \
# 0              105094.0             03/13/2023
# 1              997097.0             03/10/2023
# 2                1282.0             03/10/2023
# 3                3117.0             03/10/2023
# 4                1493.0             03/08/2023
#
#                    Type of Breach Location of Breached Information  \
# 0             Hacking/IT Incident                   Network Server
# 1             Hacking/IT Incident                   Network Server
# 2             Hacking/IT Incident                   Network Server
# 3  Unauthorized Access/Disclosure        Electronic Medical Record
# 4             Hacking/IT Incident                   Network Server
#
#   Business Associate Present Web Description               First Breach Type  \
# 0                         No             NaN             Hacking/IT Incident
# 1                         No             NaN             Hacking/IT Incident
# 2                        Yes             NaN             Hacking/IT Incident
# 3                         No             NaN  Unauthorized Access/Disclosure
# 4                         No             NaN             Hacking/IT Incident
#
#   State_AB
# 0       WI
# 1       MA
# 2       GA
# 3       IN
# 4       KS

# %%
# Define the columns you want to retrieve
columns = [
    'B01001_001E',  # Total Population
    'B01001_003E', 'B01001_004E', 'B01001_005E', 'B01001_006E',  # Males under 18
    'B01001_027E', 'B01001_028E', 'B01001_029E', 'B01001_030E',  # Females under 18
    'B01001_007E', 'B01001_008E', 'B01001_009E', 'B01001_010E', 'B01001_011E', 'B01001_012E', 'B01001_013E',  # Males 18-34
    'B01001_031E', 'B01001_032E', 'B01001_033E', 'B01001_034E', 'B01001_035E', 'B01001_036E', 'B01001_037E',  # Females 18-34
    'B01001_014E', 'B01001_015E', 'B01001_016E', 'B01001_017E', 'B01001_018E', 'B01001_019E',  # Males 35-64
    'B01001_038E', 'B01001_039E', 'B01001_040E', 'B01001_041E', 'B01001_042E', 'B01001_043E',  # Females 35-64
    'B01001_020E', 'B01001_021E', 'B01001_022E', 'B01001_023E', 'B01001_024E', 'B01001_025E',  # Males 65 and over
    'B01001_044E', 'B01001_045E', 'B01001_046E', 'B01001_047E', 'B01001_048E', 'B01001_049E'  # Females 65 and over
]

# Download the data using the censusdata package
data = censusdata.download('acs5', 2019, censusdata.censusgeo([('state', '*')]), columns)

# Calculate age demographics
data['Under 18'] = data.iloc[:, 1:9].sum(axis=1)
data['18 to 34'] = data.iloc[:, 9:23].sum(axis=1)
data['35 to 64'] = data.iloc[:, 23:35].sum(axis=1)
data['65 and Over'] = data.iloc[:, 35:47].sum(axis=1)

# Keep only the desired columns
data = data[['B01001_001E', 'Under 18', '18 to 34', '35 to 64', '65 and Over']]

# Rename the columns
data.columns = ['Total Population', 'Under 18', '18 to 34', '35 to 64', '65 and Over']

# Reset the index
data.reset_index(inplace=True)

# Extract state abbreviation from the index
data['State'] = data['index'].apply(lambda x: x.params()[0][1])

# Define a dictionary to map FIPS codes to state abbreviations
fips_to_state = {
    '01': 'AL', '02': 'AK', '04': 'AZ', '05': 'AR', '06': 'CA', '08': 'CO', '09': 'CT', '10': 'DE', '11': 'DC', '12': 'FL',
    '13': 'GA', '15': 'HI', '16': 'ID', '17': 'IL', '18': 'IN', '19': 'IA', '20': 'KS', '21': 'KY', '22': 'LA', '23': 'ME',
    '24': 'MD', '25': 'MA', '26': 'MI', '27': 'MN', '28': 'MS', '29': 'MO', '30': 'MT', '31': 'NE', '32': 'NV', '33': 'NH',
    '34': 'NJ', '35': 'NM', '36': 'NY', '37': 'NC', '38': 'ND', '39': 'OH', '40': 'OK', '41': 'OR', '42': 'PA', '44': 'RI',
    '45': 'SC', '46': 'SD', '47': 'TN', '48': 'TX', '49': 'UT', '50': 'VT', '51': 'VA', '53': 'WA', '54': 'WV', '55': 'WI',
    '56': 'WY'
}

# Map FIPS codes to state abbreviations
data['State'] = data['State'].map(fips_to_state)
# Drop the original index column
data.drop(columns=['index'], inplace=True)

# %%
df.head()
# Out:
#                Name of Covered Entity State  Covered Entity Type  \
# 0           Bone & Joint Clinic, S.C.    WI  Healthcare Provider
# 1                  ZOLL Services LLC     MA  Healthcare Provider
# 2         Colquitt Complete Care, LLC    GA  Healthcare Provider
# 3                Beacon Health System    IN  Healthcare Provider
# 4  Wichita Urology Group, PA (“WUG”)     KS  Healthcare Provider
#
#    Individuals Affected Breach Submission Date  \
# 0              105094.0             03/13/2023
# 1              997097.0             03/10/2023
# 2                1282.0             03/10/2023
# 3                3117.0             03/10/2023
# 4                1493.0             03/08/2023
#
#                    Type of Breach Location of Breached Information  \
# 0             Hacking/IT Incident                   Network Server
# 1             Hacking/IT Incident                   Network Server
# 2             Hacking/IT Incident                   Network Server
# 3  Unauthorized Access/Disclosure        Electronic Medical Record
# 4             Hacking/IT Incident                   Network Server
#
#   Business Associate Present Web Description               First Breach Type
# 0                         No             NaN             Hacking/IT Incident
# 1                         No             NaN             Hacking/IT Incident
# 2                        Yes             NaN             Hacking/IT Incident
# 3                         No             NaN  Unauthorized Access/Disclosure
# 4                         No             NaN             Hacking/IT Incident

# %%
df = df.merge(data, on="State", how="left")

# %%
df.head()
# Out:
#                Name of Covered Entity State  Covered Entity Type  \
# 0           Bone & Joint Clinic, S.C.    WI  Healthcare Provider
# 1                  ZOLL Services LLC     MA  Healthcare Provider
# 2         Colquitt Complete Care, LLC    GA  Healthcare Provider
# 3                Beacon Health System    IN  Healthcare Provider
# 4  Wichita Urology Group, PA (“WUG”)     KS  Healthcare Provider
#
#    Individuals Affected Breach Submission Date  \
# 0              105094.0             03/13/2023
# 1              997097.0             03/10/2023
# 2                1282.0             03/10/2023
# 3                3117.0             03/10/2023
# 4                1493.0             03/08/2023
#
#                    Type of Breach Location of Breached Information  \
# 0             Hacking/IT Incident                   Network Server
# 1             Hacking/IT Incident                   Network Server
# 2             Hacking/IT Incident                   Network Server
# 3  Unauthorized Access/Disclosure        Electronic Medical Record
# 4             Hacking/IT Incident                   Network Server
#
#   Business Associate Present Web Description               First Breach Type  \
# 0                         No             NaN             Hacking/IT Incident
# 1                         No             NaN             Hacking/IT Incident
# 2                        Yes             NaN             Hacking/IT Incident
# 3                         No             NaN  Unauthorized Access/Disclosure
# 4                         No             NaN             Hacking/IT Incident
#
#    Total Population   Under 18   18 to 34   35 to 64  65 and Over
# 0         5790716.0  1280903.0  1651584.0  1904658.0     953571.0
# 1         6850553.0  1371260.0  2093620.0  2278584.0    1107089.0
# 2        10403847.0  2505240.0  3149183.0  3342939.0    1406485.0
# 3         6665703.0  1572491.0  1952290.0  2117334.0    1023588.0
# 4         2910652.0   711070.0   865957.0   884298.0     449327.0

# %%
df.to_csv('breach_report')
